# %%
import pandas as pd
pengolahan_pertanian = pd.read_csv("jumlah-rumah-tangga-pengolahan-pertanian-per-provinsi-subsektor-2013.csv", delimiter = ",", encoding = "utf-8")

# %%
pengolahan_pertanian
# Out:
#      kode_provinsi                   nama_provinsi       subsektor  \
# 0             11.0  Prov. Nanggroe Aceh Darussalam  Tanaman Pangan
# 1             11.0  Prov. Nanggroe Aceh Darussalam    Hortikultura
# 2             11.0  Prov. Nanggroe Aceh Darussalam      Perkebunan
# 3             11.0  Prov. Nanggroe Aceh Darussalam      Peternakan
# 4             11.0  Prov. Nanggroe Aceh Darussalam       Perikanan
# 5             11.0  Prov. Nanggroe Aceh Darussalam       Kehutanan
# 6             12.0            Prov. Sumatera Utara  Tanaman Pangan
# 7             12.0            Prov. Sumatera Utara    Hortikultura
# 8             12.0            Prov. Sumatera Utara      Perkebunan
# 9             12.0            Prov. Sumatera Utara      Peternakan
# 10            12.0            Prov. Sumatera Utara       Perikanan
# 11            12.0            Prov. Sumatera Utara       Kehutanan
# 12            13.0            Prov. Sumatera Barat  Tanaman Pangan
# ...
